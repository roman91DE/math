# %% [markdown]
# # Basic Linear Algebra Course
#
# lessons="https://www.youtube.com/watch?v=JnTa9XtvmfI"
# textbook="https://joshua.smcvt.edu/linearalgebra/book.pdf"

# %%
import numpy as np

# %% [markdown]
# ## Linear Systems

# %%
# solve this system:

lhs = np.array([
    [(1/4) , 1 , -1],
    [1     , 4 ,  2],
    [2     ,-3 , -1]
])


var = np.array(["x", "y", "z"])

rhs = np.array([
    [0],
    [12],
    [3]
])
